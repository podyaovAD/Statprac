# %% [markdown]
# ### Import pandas, numpy and matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import the dataset from this [address]('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv')

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
    
df = pd.read_csv(url, sep = '\t')

# %% [markdown]
# ### Show the first 10 entries

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### What is the number of observations in the dataset?

# %%
len(df)
# Out:
# 4622

# %% [markdown]
# ### What is the number of columns in the dataset?

# %%
df.shape[1]
# Out:
# 5

# %% [markdown]
# ### Which was the most-ordered item and how many times it was ordered?

# %%
a=df.groupby('item_name',as_index=False)['quantity'].count()
a.sort_values('quantity',ascending=False).head(1)
# Out:
#        item_name  quantity
# 17  Chicken Bowl       726

# %% [markdown]
# ### How many different items are sold?

# %%
len(df.groupby('item_name'))
# Out:
# 50

# %% [markdown]
# ### How many items were orderd in total?

# %%
df['quantity'].sum()
# Out:
# 4972

# %% [markdown]
# ### Turn the item price into a float

# %%
df['item_price_float']=df['item_price'].apply(lambda n:float(n[1:]))
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#    item_price_float  order_price  order  ord_p
# 0              2.39         2.39   2.39   2.39
# 1              3.39         3.39   3.39   3.39
# 2              3.39         3.39   3.39   3.39
# ...

# %% [markdown]
# ### What is the price of each item?

# %%
df.groupby('item_name')['item_price_float'].mean()
# Out:
# item_name
# 6 Pack Soft Drink                         6.610185
# Barbacoa Bowl                            10.187273
# Barbacoa Burrito                          9.832418
# Barbacoa Crispy Tacos                    10.928182
# Barbacoa Salad Bowl                      10.640000
# Barbacoa Soft Tacos                      10.018400
# Bottled Water                             1.867654
# Bowl                                     14.800000
# Burrito                                   7.400000
# Canned Soda                               1.320577
# Canned Soft Drink                         1.457641
# Carnitas Bowl                            10.833971
# Carnitas Burrito                         10.132712
# Carnitas Crispy Tacos                    11.137143
# Carnitas Salad                            8.990000
# Carnitas Salad Bowl                      11.056667
# Carnitas Soft Tacos                       9.398500
# Chicken Bowl                             10.113953
# ...

# %% [markdown]
# ### How much was the revenue for the period in the dataset?

# %%
(df['item_price_float']*df['quantity']).sum()
# Out:
# 39237.02

# %% [markdown]
# ### How many orders were made in the period?

# %%
len(df['order_id'].value_counts())
# Out:
# 1834

# %% [markdown]
# ### What is the average revenue amount per order?

# %%
df['ord_p']=df['item_price_float']*df['quantity']
ordp = pd.DataFrame(df.groupby('order_id')['ord_p'].sum())
ordp.mean(0)
# Out:
# ord_p    21.394231
# dtype: float64

# %% [markdown]
# ### Merge the table ```dfa``` that contains order date and order id with ```df``` and plot daily revenue

# %%
dfa = pd.DataFrame({"date": np.random.choice(pd.date_range(start="20170101", end="20170201"), size=1800),
                   "order_id": np.arange(1800)})
res=pd.merge(dfa,df,on='order_id')
res=pd.merge(res,ordp,on='order_id' )
res
# Out:
#            date  order_id  quantity                              item_name  \
# 0    2017-01-01         1         1           Chips and Fresh Tomato Salsa
# 1    2017-01-01         1         1                                   Izze
# 2    2017-01-01         1         1                       Nantucket Nectar
# 3    2017-01-01         1         1  Chips and Tomatillo-Green Chili Salsa
# 4    2017-01-14         2         2                           Chicken Bowl
# 5    2017-01-12         3         1                           Chicken Bowl
# 6    2017-01-12         3         1                          Side of Chips
# 7    2017-01-08         4         1                          Steak Burrito
# 8    2017-01-08         4         1                       Steak Soft Tacos
# 9    2017-01-01         5         1                          Steak Burrito
# 10   2017-01-01         5         1                    Chips and Guacamole
# ...

# %%
dailyrev=res.groupby('date')['item_price_float'].sum()
dailyrev
# Out:
# date
# 2017-01-01     938.49
# 2017-01-02     968.61
# 2017-01-03    1337.20
# 2017-01-04     922.89
# 2017-01-05    1034.13
# 2017-01-06    1323.30
# 2017-01-07     858.03
# 2017-01-08     915.83
# 2017-01-09    1431.02
# 2017-01-10    1455.82
# 2017-01-11    1432.40
# 2017-01-12     892.70
# 2017-01-13    1038.37
# 2017-01-14    1018.19
# 2017-01-15     976.46
# 2017-01-16    1191.18
# 2017-01-17     830.71
# 2017-01-18     783.08
# 2017-01-19    1010.10
# 2017-01-20    1105.88
# 2017-01-21     942.11
# 2017-01-22     678.15
# 2017-01-23    1186.24
# 2017-01-24     944.79
# 2017-01-25     965.86
# 2017-01-26     969.06
# 2017-01-27     999.21
# 2017-01-28    1015.86
# 2017-01-29    1168.83
# 2017-01-30    1104.69
# 2017-01-31     948.05
# 2017-02-01    1425.86
# Name: item_price_float, dtype: float64

# %%
plt.figure(figsize=(20,10))
plt.plot(dailyrev)
plt.xlabel('Date')
plt.ylabel('Daily revenue')
plt.show()

# %% [markdown]
# ### Create a histogram of the top 5 items bought

# %%
item_quantity=pd.DataFrame(res.groupby('item_name',as_index=False)['quantity'].sum())
top5bought=pd.DataFrame(item_quantity.sort_values(by=['quantity'],ascending=[False]).head(5))
top5bought.plot.bar(x='item_name')

# %% [markdown]
# ### Sort the dataset by the name of the item

# %%
res.sort_values(by=['item_name'])
# Out:
#            date  order_id  quantity            item_name  \
# 1051 2017-01-21       432         1    6 Pack Soft Drink
# 1976 2017-01-22       798         1    6 Pack Soft Drink
# 1026 2017-01-20       422         1    6 Pack Soft Drink
# 639  2017-01-07       264         1    6 Pack Soft Drink
# 4363 2017-01-10      1742         1    6 Pack Soft Drink
# 4359 2017-01-21      1741         1    6 Pack Soft Drink
# 2108 2017-01-06       849         1    6 Pack Soft Drink
# 3141 2017-01-03      1253         1    6 Pack Soft Drink
# 298  2017-01-11       129         1    6 Pack Soft Drink
# 2232 2017-01-09       899         1    6 Pack Soft Drink
# 743  2017-01-03       306         1    6 Pack Soft Drink
# 3132 2017-01-05      1248         1    6 Pack Soft Drink
# 3010 2017-01-01      1196         1    6 Pack Soft Drink
# 1260 2017-01-29       511         1    6 Pack Soft Drink
# 341  2017-01-22       148         1    6 Pack Soft Drink
# ...

# %% [markdown]
# ### How many times were a Veggie Salad Bowl ordered?

# %%
len(df[df['item_name']=='Veggie Salad Bowl'])
# Out:
# 18

# %% [markdown]
# ### How many times people orderd more than one Canned Soda?

# %%
qcs= df[df['item_name']=='Canned Soda']
len(qcs[qcs['quantity']>=2])
# Out:
# 20

# %% [markdown]
# ### Create a scatterplot with the number of items orderered per order price

# %%
item_quantity_in_order=pd.DataFrame(res.groupby('order_id')['quantity'].sum())
scat=pd.merge(res,item_quantity_in_order, on = 'order_id')
scat=scat.rename(columns={"order_price_x": "price_for_quantity","order_price_y":"order_price","quantity_x":"quantity","quantity_y":"quantity_in_order"})
scat.sort_values(by=['order_price'],ascending = [False])
scat.plot.scatter(x='order_price',y='quantity_in_order')
plt.ylabel('Items in order')
plt.xlabel('Order price')
plt.show()

# %% [markdown]
# Submit solution to [https://goo.gl/forms/0iOA8xFJ2o5qONBr2](https://goo.gl/forms/0iOA8xFJ2o5qONBr2)
